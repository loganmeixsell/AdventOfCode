# %%
2 1
3 7
4 4
5 2,3,5 
6 0,6,9
7 8


0 a b c d e f g
1 c f 
2 a c d e g
3 a c d f g
4 b c d f
5 a b d f g
6 a b d e f g
7 a c f 
8 a b c d e f g
9 a b c d e f g 



b = g 
c = c 
d = b 
f = e

a = f
b = d
c = g
d = a
e = c
f = b
g = e
# Out:
#   File "<ipython-input-1-467c8d325d17>", line 1
#     2 1
#       ^
# SyntaxError: invalid syntax

# %%
datanew = open("Input/Day8Input.txt")
datanew = datanew.readlines()
datanew[0:5]
# datanew = datanew.strip()

# datanewsplit = datanew.split(',')
# Out:
# ['afebd ecdgfb gacfed dgaeb bf acefd fgdabec bfd bedcaf bafc | afcbed fb bfd bdf\n',
#  'eabcdg fc fbce dbfagc cagbdfe cbdge fgc gfade ecdgfb gfedc | cf fgbacd fecb becdg\n',
#  'fbeadcg fdcge deb gcdeaf fdgb bd bedacg cedbf feabc fcgdeb | dbcfeg cbeagd ebd db\n',
#  'adgcbe bgaef cab gbfadec deacg bdcg cfegad gbcea fbeadc cb | bgcd gdcb acb gabced\n',
#  'fcdbae fgadebc gefac gfda fac gcedf dgcefa dgefcb fa baceg | bdgeacf af gaecbfd cebga\n']

# %%
#part 1
tempguy = []
for x in datanew:
    tempguy.append(x.split(' | '))
outputvalues = []
learnvalues = []
count = 0
for x in tempguy:
    outputvalues.append(x[1].strip())
fixedoutputvalues = []
for x in outputvalues:
    fix = (x.split())
#     fix = x.replace(' ',',')
    fixedoutputvalues.append(fix)
uniquenums = 0
for x in fixedoutputvalues:
#     print(x)
    for y in x:
#         print(len(y))
        if len(y) == 2 or len(y) == 3 or len(y) == 4 or len(y) == 7:
#             pass
            uniquenums += 1
print(uniquenums)
# Out:
# 554

# %%
#part 2 data start
tempguy = []
for x in datanew:
    tempguy.append(x.split(' | '))
testing = []    
outputvalues = []
learnvalues = []
for x in tempguy:
    testing.append(x[0].strip())
    testing.append(x[1].strip())
    outputvalues.append(x[1].strip())
    learnvalues.append(x[0].strip())

fixedoutputvalues = []    
for x in outputvalues:
    fix = (x.split())
#     fix = x.replace(' ',',')
    fixedoutputvalues.append(fix)
fixedlearnvalues = []
for x in learnvalues:
    fix = (x.split())
    fixedlearnvalues.append(fix)

# testing
# fixedoutputvalues = []    
# for x in testing:
#     fix = (x.split())
# #     fix = x.replace(' ',',')
#     fixedoutputvalues.append(fix)

# %%
perm = permutations(['a','b','c','d','e','f','g'],7)
def HammerSolution(x):
    a = x[0]
    b = x[1]
    c = x[2]
    d = x[3]
    e = x[4]
    f = x[5]
    g = x[6]
    
    zero = a+b+c+e+f+g
    one = c+f
    two = a+c+d+e+g
    three = a+c+d+f+g
    four = b+c+d+f
    five = a+b+d+f+g
    six = a+b+d+e+f+g
    seven = a+c+f
    eight = a+b+c+d+e+f+g
    nine = a+b+c+d+f+g

    zero = sorted(zero)
    zero = "".join(zero)
    one = sorted(one)
    one = "".join(one)
    two = sorted(two)
    two = "".join(two)
    three = sorted(three)
    three = "".join(three)
    four = sorted(four)
    four = "".join(four)
    five = sorted(five)
    five = "".join(five)
    six = sorted(six)
    six = "".join(six)
    seven = sorted(seven)
    seven = "".join(seven)
    eight = sorted(eight)
    eight = "".join(eight)
    nine = sorted(nine)
    nine = "".join(nine)
#     print(zero, one, two, three, four, five, six, seven, eight, nine)
#     print(allearnvalues[0])
    answers = []
    for y in allearnvalues[0]:
#         print(y)
        if y == zero:
            answers.append(y)
            pass
        elif y == one:
#             print(y,one)
            answers.append(y)
            pass
        elif y == two:
#             print(y,two)
            answers.append(y)
            pass
        elif y == three:
#             print(y,three)
            answers.append(y)
            pass
        elif y == four:
#             print(y,four)
            answers.append(y)
            pass
        elif y == five:
#             print(y,five)
            answers.append(y)
            pass
        elif y == six:
#             print(y,six)
            answers.append(y)
            pass
        elif y == seven:
#             print(y,seven)
            answers.append(y)
            pass
        elif y == eight:
#             print(y,eight)
            answers.append(y)
            pass
        elif y == nine:
#             print(y,nine)
            answers.append(y)
            pass
        else:
            return False
#         print(answers, x, allearnvalues[0])
    return (x)
count = 0
answerswefound = []
for p in permutations(list('abcdefg')):
#     if count == 1000:
#         print(1000)
#         count = 0
    count +=1
# for x in list(perm):
#     print(x[0])

#     print(a)
    solution = HammerSolution(p)
    if solution:
        answerswefound.append(HammerSolution(p))
    else:
        pass
    
#     print(solution)
print(answerswefound)
# Out:
# [('d', 'g', 'b', 'c', 'a', 'e', 'f')]

# %%
#scratch answer
perm = permutations(['a','b','c','d','e','f','g'],7)
def HammerSolution(x, learnkey):
    a = x[0]
    b = x[1]
    c = x[2]
    d = x[3]
    e = x[4]
    f = x[5]
    g = x[6]
    
    zero = a+b+c+e+f+g
    one = c+f
    two = a+c+d+e+g
    three = a+c+d+f+g
    four = b+c+d+f
    five = a+b+d+f+g
    six = a+b+d+e+f+g
    seven = a+c+f
    eight = a+b+c+d+e+f+g
    nine = a+b+c+d+f+g

    zero = sorted(zero)
    zero = "".join(zero)
    one = sorted(one)
    one = "".join(one)
    two = sorted(two)
    two = "".join(two)
    three = sorted(three)
    three = "".join(three)
    four = sorted(four)
    four = "".join(four)
    five = sorted(five)
    five = "".join(five)
    six = sorted(six)
    six = "".join(six)
    seven = sorted(seven)
    seven = "".join(seven)
    eight = sorted(eight)
    eight = "".join(eight)
    nine = sorted(nine)
    nine = "".join(nine)
#     print(zero, one, two, three, four, five, six, seven, eight, nine)
#     print(allearnvalues[0])
    answers = []
    for y in learnkey:
#         print(y)
        if y == zero:
            answers.append(y)
            pass
        elif y == one:
#             print(y,one)
            answers.append(y)
            pass
        elif y == two:
#             print(y,two)
            answers.append(y)
            pass
        elif y == three:
#             print(y,three)
            answers.append(y)
            pass
        elif y == four:
#             print(y,four)
            answers.append(y)
            pass
        elif y == five:
#             print(y,five)
            answers.append(y)
            pass
        elif y == six:
#             print(y,six)
            answers.append(y)
            pass
        elif y == seven:
#             print(y,seven)
            answers.append(y)
            pass
        elif y == eight:
#             print(y,eight)
            answers.append(y)
            pass
        elif y == nine:
#             print(y,nine)
            answers.append(y)
            pass
        else:
            return False
#         print(answers, x, allearnvalues[0])
    return (x)
count = 0
answerswefound = []
for learnkey in allearnvalues:
    for p in permutations(list('abcdefg')):
    #     if count == 1000:
    #         print(1000)
    #         count = 0
        count +=1
    # for x in list(perm):
    #     print(x[0])

    #     print(a)
        solution = HammerSolution(p, learnkey)
        if solution:
            answerswefound.append(HammerSolution(p, learnkey))
        else:
            pass
    
#     print(solution)
print(answerswefound)
# Out:
# [('d', 'c', 'b', 'a', 'g', 'f', 'e'), ('g', 'b', 'f', 'e', 'a', 'c', 'd'), ('e', 'g', 'b', 'f', 'a', 'd', 'c'), ('a', 'd', 'b', 'g', 'f', 'c', 'e'), ('c', 'd', 'a', 'g', 'b', 'f', 'e'), ('g', 'e', 'b', 'a', 'c', 'd', 'f'), ('d', 'c', 'b', 'e', 'g', 'f', 'a'), ('a', 'c', 'd', 'e', 'g', 'f', 'b'), ('b', 'd', 'a', 'e', 'g', 'c', 'f'), ('a', 'c', 'g', 'b', 'e', 'd', 'f'), ('b', 'f', 'e', 'g', 'd', 'a', 'c'), ('c', 'd', 'b', 'a', 'g', 'f', 'e'), ('b', 'a', 'd', 'g', 'c', 'f', 'e'), ('f', 'b', 'a', 'c', 'd', 'g', 'e'), ('b', 'f', 'e', 'd', 'g', 'a', 'c'), ('e', 'a', 'g', 'f', 'd', 'b', 'c'), ('g', 'b', 'f', 'e', 'c', 'a', 'd'), ('a', 'f', 'c', 'd', 'g', 'e', 'b'), ('a', 'c', 'e', 'd', 'f', 'b', 'g'), ('d', 'g', 'c', 'b', 'f', 'a', 'e'), ('a', 'c', 'b', 'e', 'f', 'd', 'g'), ('b', 'd', 'e', 'f', 'g', 'a', 'c'), ('g', 'c', 'd', 'e', 'a', 'b', 'f'), ('d', 'g', 'f', 'c', 'b', 'a', 'e'), ('a', 'g', 'd', 'b', 'e', 'c', 'f'), ('e', 'c', 'f', 'b', 'g', 'a', 'd'), ('e', 'b', 'c', 'f', 'g', 'a', 'd')
# ...

# %%
finalanswers = []
for count,value in enumerate(answerswefound):
#     print(count,value)
    a = value[0]
    b = value[1]
    c = value[2]
    d = value[3]
    e = value[4]
    f = value[5]
    g = value[6]
    
    zero = a+b+c+e+f+g
    one = c+f
    two = a+c+d+e+g
    three = a+c+d+f+g
    four = b+c+d+f
    five = a+b+d+f+g
    six = a+b+d+e+f+g
    seven = a+c+f
    eight = a+b+c+d+e+f+g
    nine = a+b+c+d+f+g

    zero = sorted(zero)
    zero = "".join(zero)
    one = sorted(one)
    one = "".join(one)
    two = sorted(two)
    two = "".join(two)
    three = sorted(three)
    three = "".join(three)
    four = sorted(four)
    four = "".join(four)
    five = sorted(five)
    five = "".join(five)
    six = sorted(six)
    six = "".join(six)
    seven = sorted(seven)
    seven = "".join(seven)
    eight = sorted(eight)
    eight = "".join(eight)
    nine = sorted(nine)
    nine = "".join(nine)
    answers = []
    for y in aloutputvalues[count]:
        if y == zero:
            answers.append(0)
            pass
        elif y == one:
#             print(y,one)
            answers.append(1)
            pass
        elif y == two:
#             print(y,two)
            answers.append(2)
            pass
        elif y == three:
#             print(y,three)
            answers.append(3)
            pass
        elif y == four:
#             print(y,four)
            answers.append(4)
            pass
        elif y == five:
#             print(y,five)
            answers.append(5)
            pass
        elif y == six:
#             print(y,six)
            answers.append(6)
            pass
        elif y == seven:
#             print(y,seven)
            answers.append(7)
            pass
        elif y == eight:
#             print(y,eight)
            answers.append(8)
            pass
        elif y == nine:
#             print(y,nine)
            answers.append(9)
            pass
    finalanswers.append(answers)
print(finalanswers)

totalsum = 0
for x in finalanswers:
    totalsum += int(f"{x[0]}{x[1]}{x[2]}{x[3]}")
print(totalsum)
# Out:
# [[9, 1, 7, 7], [1, 0, 4, 5], [9, 0, 7, 1], [4, 4, 7, 9], [8, 1, 8, 2], [8, 8, 7, 5], [1, 3, 8, 8], [1, 7, 8, 8], [1, 4, 1, 6], [6, 4, 8, 4], [7, 6, 4, 8], [2, 4, 7, 7], [1, 4, 7, 8], [1, 1, 1, 8], [7, 9, 8, 1], [9, 6, 4, 1], [7, 5, 7, 4], [9, 1, 3, 4], [2, 1, 1, 4], [4, 4, 4, 0], [7, 2, 4, 4], [1, 7, 4, 7], [2, 7, 4, 7], [9, 6, 2, 2], [8, 3, 8, 8], [7, 6, 8, 9], [8, 8, 3, 8], [4, 3, 7, 2], [4, 1, 9, 8], [8, 0, 0, 4], [1, 7, 1, 7], [9, 1, 1, 8], [7, 3, 1, 4], [1, 8, 4, 3], [1, 7, 8, 6], [4, 9, 8, 7], [8, 7, 7, 7], [4, 4, 0, 9], [1, 0, 1, 3], [1, 4, 4, 3], [3, 7, 8, 7], [9, 4, 2, 8], [1, 3, 9, 4], [4, 8, 6, 4], [5, 0, 1, 4], [8, 8, 4, 9], [8, 1, 4, 2], [3, 4, 8, 9], [1, 8, 6, 1], [3, 1, 5, 0], [7, 7, 8, 8], [4, 8, 8, 1], [8, 8, 6, 1], [9, 7, 0, 9], [8, 9, 0, 7], [4, 4, 4, 7], [7, 9, 2, 8], [3, 8, 7, 8], [7, 7, 7, 4], [8, 8, 8, 5], [0, 2, 4, 8], [8, 4, 4, 3], [7, 1, 8, 3], [4, 7, 8, 7], [3, 1, 4, 6], [7, 3, 0, 4], [1, 7, 3, 5], [1, 4, 3, 7], [4, 3, 7, 4], [9, 7, 8, 8], [0, 9, 6, 6], [3,
# ...

# %%
def HammerSolution():
    for x in whatamidoing[0]:
        if len(x) == 2:
            if one == x:
                print("success!")
        elif len(x) == 3:
            if three == x:
                print("success!")
        elif len(x) == 4:
            if four == x:
                print("success!")
            else:
                return False
        elif len(x) == 7:
            if eight == x:
                print("success!")
            else:
                return False
        elif len(x) == 5:
            if two == x or three == x or five == x:
                print("success!")
            else:
                return False
        elif len(x) == 6:
            if zero == x or six == x or nine == x:
                print("success!")
            else:
                return False
    return True

# %%
# Out:
# 990964

# %%
aloutputvalues = []
for xcount,valuecount in enumerate(fixedoutputvalues):
    ihavenoidea = []
    for count,value in enumerate(fixedoutputvalues[xcount]): 
        sorted_characters = sorted(fixedoutputvalues[xcount][count])
        string = "".join(sorted_characters)
        ihavenoidea.append(string)
#         print(string)
#         print (fixedoutputvalues[xcount][count])
#         print(xcount,count)
    aloutputvalues.append(ihavenoidea)
aloutputvalues[0:10]
# Out:
# [['abcdef', 'bf', 'bdf', 'bdf'],
#  ['cf', 'abcdfg', 'bcef', 'bcdeg'],
#  ['bcdefg', 'abcdeg', 'bde', 'bd'],
#  ['bcdg', 'bcdg', 'abc', 'abcdeg'],
#  ['abcdefg', 'af', 'abcdefg', 'abceg'],
#  ['abcdefg', 'abcdefg', 'bdg', 'adefg'],
#  ['bf', 'abdef', 'abcdefg', 'abcdefg'],
#  ['df', 'adf', 'abcdefg', 'abcdefg'],
#  ['ac', 'acde', 'ac', 'bcdefg'],
#  ['abcdef', 'bcdg', 'abcdefg', 'bcdg']]

# %%
allearnvalues = []
for xcount,valuecount in enumerate(fixedlearnvalues):
    ihavenoidea = []
    for count,value in enumerate(fixedlearnvalues[xcount]): 
        sorted_characters = sorted(fixedlearnvalues[xcount][count])
        string = "".join(sorted_characters)
        ihavenoidea.append(string)
#         print(string)
#         print (fixedoutputvalues[xcount][count])
#         print(xcount,count)
    allearnvalues.append(ihavenoidea)
allearnvalues[1]
# Out:
# ['abcdeg',
#  'cf',
#  'bcef',
#  'abcdfg',
#  'abcdefg',
#  'bcdeg',
#  'cfg',
#  'adefg',
#  'bcdefg',
#  'cdefg']
